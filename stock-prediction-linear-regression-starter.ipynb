# %% [markdown]
# ### 股票预测小案例
# 我们要做股票的预测，针对于历史数据来预测股价的走势。在这里，我们要解决的具体问题为：给定历史数据来预测5天之后的股价。
# 这个问题是经典的回归问题，所以可以使用线性回归模型来解决。
#
# 在这个项目中，需要做如下的几件事情：
# 1. 读取某一只股票行情数据，并试着理解每一个字段的含义
# 2. 对于读取之后的数据，做一些必要的预处理（如排序，去掉NAN，把字符串转换成日期等）
# 3. 提取特征值和预测值，分别保存为X, y两个变量中
# 4. 把数据分为训练和测试数据
# 5. 在训练数据中训练模型，在测试数据中测试模型的效果
# 6. 做简单的可视化展示
# 7. 分析特征的重要性，这部分可以从学出来的权重获得。
#
# 在标记为```TODO```的地方，填写必要的代码

# %% [markdown]
# ### 1. 数据的读取和数据预处理

# %%
# 导入必要的库
import numpy as np # 数学计算
import pandas as pd # 数据处理, 读取 CSV 文件 (e.g. pd.read_csv)
import matplotlib.pyplot as plt # 可视化工具
from datetime import datetime as dt  # 时间的工具
from sklearn import preprocessing  # 归一化时用到

# %%
# 对于股票数据，你可以使用如下的方法下载某一个公司的股票交易历史
# 000001 为平安银行
# 如果你还没有安装, 可以使用 pip install tushare 安装tushare python包
# import tushare as ts
# df = ts.get_hist_data('000001')
# print(df)
# df.to_csv('000001.csv')

# %%
# 读取股票代码为000001的行情数据
df = pd.read_csv('./000001.csv')

# %%
print(np.shape(df))
df.head()
# Out:
# (611, 14)
#          date   open   high  close    low      volume  price_change  p_change  \
# 0  2019-05-30  12.32  12.38  12.22  12.11   646284.62         -0.18     -1.45
# 1  2019-05-29  12.36  12.59  12.40  12.26   666411.50         -0.09     -0.72
# 2  2019-05-28  12.31  12.55  12.49  12.26   880703.12          0.12      0.97
# 3  2019-05-27  12.21  12.42  12.37  11.93  1048426.00          0.02      0.16
# 4  2019-05-24  12.35  12.45  12.35  12.31   495526.19          0.06      0.49
#
#       ma5    ma10    ma20      v_ma5     v_ma10      v_ma20
# 0  12.366  12.390  12.579  747470.29  739308.42   953969.39
# 1  12.380  12.453  12.673  751584.45  738170.10   973189.95
# 2  12.380  12.505  12.742  719548.29  781927.80   990340.43
# 3  12.394  12.505  12.824  689649.77  812117.30  1001879.10
# 4  12.396  12.498  12.928  637251.61  781466.47  1046943.98

# %% [markdown]
# 股票数据的特征
#
# * date：日期
# * open：开盘价
# * high：最高价
# * close：收盘价
# * low：最低价
# * volume：成交量
# * price_change：价格变动
# * p_change：涨跌幅
# * ma5：5日均价
# * ma10：10日均价
# * ma20:20日均价
# * v_ma5:5日均量
# * v_ma10:10日均量
# * v_ma20:20日均量

# %%
# 将每一个数据的键值的类型从字符串转为日期，并把date字段设置为index
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

# TODO: 按照时间升序排列数据, 使用df中的sort_values函数
#
#
df.head(10)
# Out:
#             open  high  close   low      volume  price_change  p_change  \
# date
# 2016-11-29  9.59  9.70   9.62  9.55   887779.19         -0.01     -0.10
# 2016-11-30  9.65  9.72   9.55  9.50  1025963.06         -0.07     -0.73
# 2016-12-01  9.57  9.63   9.60  9.55   646004.38          0.05      0.52
# 2016-12-02  9.60  9.60   9.55  9.44   829686.50         -0.05     -0.52
# 2016-12-05  9.50  9.54   9.46  9.41   764365.69         -0.09     -0.94
# 2016-12-06  9.48  9.52   9.49  9.45   602902.75          0.03      0.32
# 2016-12-07  9.48  9.49   9.48  9.41   493404.75         -0.01     -0.10
# 2016-12-08  9.50  9.55   9.52  9.43   671452.19          0.04      0.42
# 2016-12-09  9.50  9.75   9.65  9.48  1514199.25          0.13      1.37
# 2016-12-12  9.65  9.77   9.50  9.44  1256874.00         -0.15     -1.55
#
#               ma5   ma10   ma20      v_ma5     v_ma10     v_ma20
# date
# 2016-11-29  9.620  9.620  9.620  887779.19  887779.19  887779.19
# 2016-11-30  9.585  9.585  9.585  956871.13  956871.13  956871.13
# 2016-12-01  9.590  9.590  9.590  853248.88  853248.88  853248.88
# 2016-12-02  9.580  9.580  9.580  847358.28  847358.28  847358.28
# 2016-12-05  9.556  9.556  9.556  830759.76  830759.76  830759.76
# 2016-12-06  9.530  9.545  9.545  773784.48  792783.60  792783.60
# 2016-12-07  9.516  9.536  9.536  667272.81  750015.19  750015.19
# 2016-12-08  9.500  9.534  9.534  672362.38  740194.81  740194.81
# 2016-12-09  9.520  9.547  9.547  809264.93  826195.31  826195.31
# 2016-12-12  9.528  9.542  9.542  907766.59  869263.18  869263.18

# %%
# 检测是否有缺失数据 NaNs
df.dropna(axis=0 , inplace=True)
df.isna().sum()
# Out:
# open            0
# high            0
# close           0
# low             0
# volume          0
# price_change    0
# p_change        0
# ma5             0
# ma10            0
# ma20            0
# v_ma5           0
# v_ma10          0
# v_ma20          0
# dtype: int64

# %%
min_date = df.index.min()
max_date = df.index.max()
print ("First date is",min_date)
print ("Last date is",max_date)
# Out:
# First date is 2016-11-29 00:00:00
# Last date is 2019-05-30 00:00:00

# %% [markdown]
# ### 2. 构建特征向量X和预测值y

# %%
# 创建新的一列（预测值）。预测值为5天之后的收盘价，使用shift函数来实现。 
# TODO： 
num = 5 # 预测5天后的情况
df['label'] = 
print(df.shape)
# Out:
# (611, 14)

# %%
df.tail(10)
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2019-05-17  12.92  12.93  12.44  12.36   965000.88         -0.41     -3.19
# 2019-05-20  12.35  12.54  12.38  12.25   786435.19         -0.06     -0.48
# 2019-05-21  12.40  12.73  12.56  12.36   731210.50          0.18      1.45
# 2019-05-15  12.510  12.892  13.560  1155611.00  1208209.79  1254306.88  12.40
# 2019-05-16  12.648  12.767  13.518   971160.96  1168630.36  1209357.42  12.29
# 2019-05-17  12.600  12.626  13.411   925681.34  1153473.43  1138638.70  12.35
# 2019-05-20  12.616  12.577  13.312   934584.83  1021250.17  1127754.97  12.37
# 2019-05-21  12.630  12.538  13.223   844307.30   987105.38  1138963.23  12.49
# 2019-05-22  12.526  12.518  13.107   724755.75   940183.37  1101972.96  12.40
# 2019-05-23  12.414  12.531  13.014   731146.55   851153.75  1069202.04  12.22

# %%
# 构建特征向量X，也就是数据中的X。由于我们要预测df['label']值，需要先去掉，不然就失去预测意义了。 另外，
# 在本次预测任务中先不考虑"price_change"和"p_change"两个字段。 
X = df.drop(['price_change', 'label', 'p_change'],axis=1)
X = X.values

# TODO： 使用z-score normalization做归一化，参考preprocessing模块里的scale函数的使用
X =

# %%
# 提取预测值
y = df.label.values

# %%
print(np.shape(X), np.shape(y))
# Out:
# (606, 11) (606,)

# %%
# 把数据分为训练和测试数据。我们把一开始的550个样本作为训练数据，之后的样本作为
# 测试数据
X_train, y_train = X[0:550, :], y[0:550]
X_test, y_test = X[550:606,:], y[550:606]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (550, 11)
# (550,)
# (56, 11)
# (56,)

# %% [markdown]
# ### 3. 训练模型

# %%
# 训练线性回归模型

# TODO：导入相应的线性回归库
from 

# TODO: 在训练数据上训练线性回归模型
lr =
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.score(X_test, y_test) # 使用绝对系数 R^2 评估模型
# Out:
# 0.04930040648385503

# %% [markdown]
# ### 4. 可视化结果（预测值 vs 真实值）

# %%
# 输出针对最后五个样本的预测，以及真实值
x_predict = X[-100:]  # 选取最新的100个样本
forcast = lr.predict(x_predict) # 预测

plt.plot(y[-100:], color='r' , label="actual value")  
plt.plot(forcast, color='b', label="predicted value")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %% [markdown]
# ### 5. 观察模型的权重。在线性回归中，权重（绝对值）越大，就意味着跟预测值之间的关系就越大

# %%
# 理解模型，查看哪些特征对结果的影响比较大
for idx, col_name in enumerate(['open', 'high', 'close', 'low', 'volume', 'ma5', 'ma10', 'ma20', 'v_ma5', 'v_ma10', 'v_ma20']):
    print("The coefficient for {} is {}".format(col_name, lr.coef_[idx]))
# Out:
# The coefficient for open is -0.7623399996475246
# The coefficient for high is 0.8321435171405481
# The coefficient for close is 0.24463705375238515
# The coefficient for low is 1.091415550493549
# The coefficient for volume is 0.004380793756912541
# The coefficient for ma5 is -0.30717535019465386
# The coefficient for ma10 is 0.19354310799475685
# The coefficient for ma20 is 0.2490207748469822
# The coefficient for v_ma5 is 0.17472336466033703
# The coefficient for v_ma10 is 0.08873934447969938
# The coefficient for v_ma20 is -0.2791070269442078
